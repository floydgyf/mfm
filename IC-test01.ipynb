# %% [markdown]
# # 多因子模型（参考安信）

# %%
# 加载库
import numpy as np
import pandas as pd

# 文件名
DATAFILE = 'financial_data_20170323.xlsx'  # put your file path here

# %%
# 读取数据，处理数据
df = pd.read_excel(DATAFILE)

# %%
# for test
df.head()
# Out:
#             AMT  APTURNDAYS  ARTURN  ASSETSTURN  CASHRATIO  \
# 0  8.279756e+10         NaN     NaN      0.0063        NaN
# 1  5.843115e+10         NaN     NaN      0.0136        NaN
# 2  6.460645e+10         NaN     NaN      0.0216        NaN
# 3  5.949293e+10         NaN     NaN      0.0298        NaN
# 4  3.474943e+10         NaN     NaN      0.0081        NaN
#
#    CASH_RECP_SG_AND_RS  CATOASSETS     CLOSE  CURRENT  DEBTTOASSETS  \
# 0                  NaN         NaN  6.947486      NaN       95.0996
# 1                  NaN         NaN  5.556786      NaN       94.9895
# 2                  NaN         NaN  6.621326      NaN       94.8851
# 3                  NaN         NaN  6.827545      NaN       94.0752
# 4                  NaN         NaN  6.002666      NaN       94.4066
#
#      ...      TOT_OPER_COST  TOT_OPER_REV    TOT_PROFIT  TRADE_CODE  \
# 0    ...       6.085000e+09  1.080200e+10  4.718000e+09         1.0
# ...
